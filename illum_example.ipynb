# %%
source("illum_utils.R")

# %% [markdown]
# ### Young and short-term:

# %%
gse_names <- c("GSE49000","GSE39313")
data_dir <- paste(getwd(), "data", sep="/")

# %%
#get raw data
get_raw(gse_names, data_dir)
# Out:
# ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE49nnn/GSE49000/suppl/
# ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE39nnn/GSE39313/suppl/
# [[1]]
# /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE49000/GSE49000_non-normalized.txt.gz
#                                                                                           9535812
#
# [[2]]
# /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE39313/GSE39313_non-normalized.txt.gz
#                                                                                          20721011

# %%
#open/edit raw data
gse_names <- open_raw(gse_names, data_dir)
gse_names
# Out:
# [1] "GSE49000" "GSE39313"

# %%
#load esets
esets <- load_eset(gse_names, data_dir)
# Out:
# ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE40nnn/GSE40936/matrix/
# Found 1 file(s)
# GSE40936_series_matrix.txt.gz
# Using locally cached version: /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE40936/GSE40936_series_matrix.txt.gz
# Using locally cached version of GPL6885 found here:
# /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE40936/GPL6885.soft
# Reading file /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE40936/GSE40936_GEO_Supplementary_file_AS_Liver_9-14-12_non-normalized.txt ... ...
# Reading file /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE40936/GSE40936_GEO_Supplementary_file_AS_Muscle_9-14-12_non-normalized.txt ... ...
# Note: inferring mean and variance of negative control probe intensities from the detection p-values.
# Loading required package: illuminaMousev2.db

# %%
diff_exprs <- diff_expr(esets, data_dir)
# Out:
# Number of significant surrogate variables is:  3
# Iteration (out of 5 ):1  2  3  4  5  Features  Samples
#    25694       10
# Features  Samples
#    11682       10
#
#
# CR-AL (n significant): 260
# Plot with title “GSE40936”

# %% [markdown]
# ### Old and long-term:

# %%
gse_names <- c("GSE62194","GSE46895", "GSE40936", "GSE36285", 
               "GSE52825", "GSE40977", "GSE23218", "GSE11845")

data_dir <- paste(getwd(), "data", sep="/")

#get raw data
get_raw(gse_names, data_dir)

# %%
#open/edit raw data
gse_names <- open_raw(gse_names, data_dir)
gse_names
# Out:
# [1] "GSE62194" "GSE46895" "GSE40936" "GSE36285" "GSE52825" "GSE40977" "GSE23218"
# [8] "GSE11845"

# %%
#load esets
esets <- load_eset(gse_names, data_dir)
# Out:
# ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE62nnn/GSE62194/matrix/
# Found 1 file(s)
# GSE62194_series_matrix.txt.gz
# Using locally cached version of GPL6885 found here:
# /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE62194/GPL6885.soft
# Reading file /home/alex/Documents/Batcave/GEO/caloric-restriction/data/GSE62194/GSE62194_non-normalized.txt ... ...
# Note: inferring mean and variance of negative control probe intensities from the detection p-values.
# [1] 25697    71
# [1] 25697    71
# ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE46nnn/GSE46895/matrix/
# Found 1 file(s)
# GSE46895_series_matrix.txt.gz
